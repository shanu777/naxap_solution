# %%
import tensorflow.keras
from PIL import Image, ImageOps
import numpy as np

# %%
import os

# %%
r=0
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = tensorflow.keras.models.load_model('keras_model.h5')

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1.
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
images=os.listdir("C:/Users/utkarsh/test_images/")
# Replace this with the path to your image
r=0
for img in images:    
    image = cv2.imread("C:/Users/utkarsh/test_images/"+img)
    img=cv2.resize(image,(224,224))
    im_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    normalized_im_array = (im_rgb.astype(np.float32) / 127.0) - 1
    data_im=np.expand_dims(normalized_im_array,axis=0)
    prediction_im = model.predict(data_im)

    if prediction_im[0][0]>prediction[0][1]:
        cv2.imwrite("C:/Users/utkarsh/predictions/human/"+str(r)+".jpg",image)
        plt.imshow(image)
        print('human')
    else:
        cv2.imwrite("C:/Users/utkarsh/predictions/no human/"+str(r)+".jpg",image)
        plt.imshow(image)
        print('not human')
    r+=1
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# human
# not human
# not human
# not human
# not human
# human
# not human
# not human
# not human
# not human
# not human
# human
# not human
# not human
# human
# not human
# human
# human
# not human
# human
# human
# not human
# human
# human
# human
# not human
# not human
# not human
# human
# human
# human
# human
# not human
# not human
# human
# human
# not human
# human
# not human
# not human
# not human
# not human
# not human
# not human
# not human
# not human
# human
# human
# not human
# not human
# human
# human
# human
# not human
# not human
# human
# human
# not human
# not human
# not human
# human
# human
# not human
# not human
# not human
# human
# not human
# not human
# not human
# not human
# not human
# not human
# human
# not human
# not human
# not human
# human
# not human
# not human
# not human
# human
# not human
# not human
# ...
